# %% [markdown]
# # Code Red: The Business Impact of Code Quality
#
# This notebook contains the complete replication package, including raw data and scripts for the statistical analysis, for the paper "Code Red: The Business Impact of Code Quality: A Quantitative Study of 39 Proprietary Production Codebases" by Adam Tornhill & Markus Borg, 2022.
#
# The data is based on the [Code Health metric](https://codescene.com/code-health/) and collected via CodeScene.

# %%
# !conda install -y pandas
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/adam/opt/miniconda3/envs/ml
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2021.10.8          |   py39hecd8cb5_2         152 KB
#     openssl-1.1.1m             |       hca72f7f_0         2.2 MB
#     pandas-1.3.5               |   py39h743cdd8_0         9.2 MB
#     ------------------------------------------------------------
#                                            Total:        11.6 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2021.10.~ --> pkgs/main::ca-certificates-2021.10.26-hecd8cb5_2
#   certifi            conda-forge::certifi-2021.10.8-py39h6~ --> pkgs/main::certifi-2021.10.8-py39hecd8cb5_2
#   openssl            conda-forge::openssl-1.1.1l-h0d85af4_0 --> pkgs/main::openssl-1.1.1m-hca72f7f_0
#   pandas                               1.3.4-py39h743cdd8_0 --> 1.3.5-py39h743cdd8_0
#
#
#
# Downloading and Extracting Packages
# pandas-1.3.5         | 9.2 MB    | ##################################### | 100%
# certifi-2021.10.8    | 152 KB    | ##################################### | 100%
# openssl-1.1.1m       | 2.2 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ## Data collection and preparation
#
# Read the CSV, and make sure we add the code health category which we use as the independent variable in the calculations:

# %%
import pandas as pd

def _by_code_health_category(df):
    def v_to_category(v):
        if v < 4.0:
            return 'alert'
        if v < 9.0:
            return 'warning'
        return 'healthy'

    code_health_categories = [v_to_category(v) for v in df['code_health_now']]
    df['code_health_category'] = code_health_categories

def read_cleaned_data_from(file_name):
    df = pd.read_csv(file_name, sep=';', decimal=",")
    
    _by_code_health_category(df)
    
    return _keep_entities_with_issues(df)

# %%
df = read_cleaned_data_from('./data/code_health_ct_data.csv')

# %%
df.describe()
# Out:
#               index        issues  mean_time_for_issue  lines_of_code  \
# count  30737.000000  30737.000000         2.538600e+04   25386.000000
# mean    2083.158831      4.170023         8.573125e+03     122.128338
# std     2024.517390      7.126601         2.539253e+04     520.709154
# min        0.000000      1.000000         6.000000e+01       0.000000
# 25%      441.000000      1.000000         1.560000e+03      11.000000
# 50%     1397.000000      2.000000         3.360000e+03      49.000000
# 75%     3251.000000      4.000000         8.014500e+03     127.000000
# max     8395.000000    293.000000         1.452780e+06   72630.000000
#
#        code_health_now         total  max_time_for_issue  total_defects
# count     30737.000000  3.073700e+04        3.073700e+04   30737.000000
# mean          9.577271  3.225713e+04        1.828689e+04       0.353743
# std           1.104758  1.000183e+05        4.849241e+04       1.433712
# min           1.000000  6.000000e+01        6.000000e+01       0.000000
# 25%           9.750000  2.940000e+03        2.280000e+03       0.000000
# 50%          10.000000  9.060000e+03        6.180000e+03       0.000000
# 75%          10.000000  2.700000e+04        1.626000e+04       0.000000
# max          10.000000  5.985900e+06        1.452780e+06      58.000000

# %% [markdown]
# To meet the pre-conditions for an ANOVA, we must ensure normality of the dependent variables. We normalize DV-RQ2 and DV-RQ3 using the Yeo-Johnson algorithm. The scaled values are used for plots and descriptive statistics.

# %%
from scipy import stats
import math
# Yeo-Johnson transform
from sklearn.preprocessing import PowerTransformer
import numpy as np

def _scale(df, column_to_scale):
    max_v = df[column_to_scale].max()
    
    def v_to_scaled(v):
        return v / max(max_v, 1)
    
    scaled = [v_to_scaled(v) for v in df[column_to_scale]]
    df[column_to_scale + '_scaled'] = scaled
    return df

def _normalize_yj_transform(df, column_to_normalize):
    pt = PowerTransformer(method='yeo-johnson')
    
    data = np.array(df[column_to_normalize])
    reshaped_data = np.array(data).reshape(-1, 1)
    
    pt.fit(reshaped_data)
    df[column_to_normalize + '_norm'] = pt.transform(reshaped_data)
    return df
    
def normalize_combined_df(df):
    _scale(df, 'total_defects')
    
    
    # graphs with denormalized cycle times are much easier to interpret.
    # however, we need to have the data follow a normal distribution to make significance tests with an ANOVA:

    _normalize_yj_transform(df, 'max_time_for_issue')
    _scale(df, 'max_time_for_issue')
    _scale(df, 'max_time_for_issue_norm')
    
    _scale(df, 'mean_time_for_issue')
    _normalize_yj_transform(df, 'mean_time_for_issue')
    _normalize_yj_transform(df, 'mean_time_for_issue_scaled')
    
    return df

# %%
df = normalize_combined_df(df)

# %%
df.describe()
# Out:
#               index        issues  mean_time_for_issue  lines_of_code  \
# count  30737.000000  30737.000000         2.538600e+04   25386.000000
# mean    2083.158831      4.170023         8.573125e+03     122.128338
# std     2024.517390      7.126601         2.539253e+04     520.709154
# min        0.000000      1.000000         6.000000e+01       0.000000
# 25%      441.000000      1.000000         1.560000e+03      11.000000
# 50%     1397.000000      2.000000         3.360000e+03      49.000000
# 75%     3251.000000      4.000000         8.014500e+03     127.000000
# max     8395.000000    293.000000         1.452780e+06   72630.000000
#
#        code_health_now         total  max_time_for_issue  total_defects  \
# count     30737.000000  3.073700e+04        3.073700e+04   30737.000000
# mean          9.577271  3.225713e+04        1.828689e+04       0.353743
# std           1.104758  1.000183e+05        4.849241e+04       1.433712
# min           1.000000  6.000000e+01        6.000000e+01       0.000000
# 25%           9.750000  2.940000e+03        2.280000e+03       0.000000
# 50%          10.000000  9.060000e+03        6.180000e+03       0.000000
# 75%          10.000000  2.700000e+04        1.626000e+04       0.000000
# max          10.000000  5.985900e+06        1.452780e+06      58.000000
#
#        total_defects_scaled  max_time_for_issue_norm  \
# count          30737.000000             3.073700e+04
# mean               0.006099             3.323409e-16
# std                0.024719             1.000016e+00
# min                0.000000            -2.693156e+00
# 25%                0.000000            -6.281784e-01
# 50%                0.000000             4.934223e-03
# 75%                0.000000             6.483869e-01
# max                1.000000             4.053583e+00
#
#        max_time_for_issue_scaled  max_time_for_issue_norm_scaled  \
# count               30737.000000                    3.073700e+04
# mean                    0.012588                    6.291938e-17
# std                     0.033379                    2.466993e-01
# min                     0.000041                   -6.643890e-01
# 25%                     0.001569                   -1.549687e-01
# 50%                     0.004254                    1.217250e-03
# 75%                     0.011192                    1.599540e-01
# max                     1.000000                    1.000000e+00
#
#        mean_time_for_issue_scaled  mean_time_for_issue_norm  \
# count                25386.000000              2.538600e+04
# mean                     0.005901             -5.173081e-16
# std                      0.017479              1.000020e+00
# min                      0.000041             -2.821856e+00
# 25%                      0.001074             -6.001037e-01
# 50%                      0.002313             -3.509032e-02
# 75%                      0.005517              6.246014e-01
# max                      1.000000              5.038840e+00
#
#        mean_time_for_issue_scaled_norm
# count                     2.538600e+04
# mean                      2.369578e-16
# std                       1.000020e+00
# min                      -1.264292e+00
# 25%                      -7.927589e-01
# 50%                      -3.079324e-01
# 75%                       6.248456e-01
# max                       2.348651e+00

# %%
### Visualize the normality of our dependent variables

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax=plt.subplots(1,2)

sns.distplot(df['max_time_for_issue_scaled'], ax=ax[0])
ax[0].set_title('Original Data (max time)')

sns.distplot(df['max_time_for_issue_norm_scaled'], ax=ax[1])
ax[1].set_title('Normalized Data (max time')
# Out:
# /Users/adam/opt/miniconda3/envs/ml/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/adam/opt/miniconda3/envs/ml/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Normalized Data (max time')

# %%
fig, ax=plt.subplots(1,2)

sns.distplot(df['mean_time_for_issue_scaled'], ax=ax[0])
ax[0].set_title('Original Data (mean time)')

sns.distplot(df['mean_time_for_issue_norm'], ax=ax[1])
ax[1].set_title('Normalized Data (mean time)')
# Out:
# /Users/adam/opt/miniconda3/envs/ml/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/adam/opt/miniconda3/envs/ml/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Normalized Data (mean time)')

# %% [markdown]
# ### Descriptive graphs
#
# Visualize the programming language statistics:

# %%
ax_lang = sns.countplot(data=df, x='language', order=df['language'].value_counts().index)
ax_lang.set(xlabel='Programming Language', ylabel='Number of files', title='Overview of included programming languages')
plt.setp(ax_lang.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.show(ax_lang)

# %% [markdown]
# ## Statistical tests
#
# Split the distribution into three groups, each one representing a code health category:

# %%
healthy = df[df['code_health_category']=='healthy']
warning = df[df['code_health_category']=='warning']
alert = df[df['code_health_category']=='alert']

# %% [markdown]
# ### [RQ1] How does the number of reported defects in source code files correlate to source code quality?
#
# We use the Anderson-Darling test (A-D test), which is a modification of Kolmogorov-Smirnov test. A-D tests whether a given sample of observations is drawn from a given probability distribution (in our case from normal distribution). The null hypothesis is that the samples are *not* from a normal distribution.

# %%
from scipy.stats import anderson

result = (anderson(df['total_defects_scaled'], dist='norm'))

print(f"A-D statistic: {result[0]}")
print(f"Critical values: {result[1]}")
print(f"Significance levels: {result[2]}")
# Out:
# A-D statistic: 7719.706302409184
# Critical values: [0.576 0.656 0.787 0.918 1.092]
# Significance levels: [15.  10.   5.   2.5  1. ]

# %% [markdown]
# Since we don't have sampels from a normal distribution, we use a significance test for non-normal distribution using the Kruskal-Wallis Test:

# %%
from scipy import stats

#perform Kruskal-Wallis Test: it is considered to be the non-parametric equivalent of the One-Way ANOVA.
stats.kruskal(healthy['total_defects_scaled'], warning['total_defects_scaled'], alert['total_defects_scaled'])
# Out:
# KruskalResult(statistic=1645.0453054602567, pvalue=0.0)

# %%
# Multiple comparisons are done using DSCF

import scikit_posthocs as sp

sp.posthoc_dscf(df,val_col="total_defects_scaled",group_col="code_health_category")
# Out:
#          healthy  warning  alert
# healthy    1.000    0.001  0.001
# warning    0.001    1.000  0.001
# alert      0.001    0.001  1.000

# %% [markdown]
# Add visual plots of the results to highlight the differences in means:

# %%
def show_total_defects_by_code_health_for(df):
    bx = sns.barplot(x="code_health_category", y="total_defects_scaled", data=df, order=['healthy', 'warning', 'alert'], palette="Blues_d")
    bx.set(xlabel='Code health category', ylabel='Defects per File', title='Defects by Code Health category')
    plt.show(bx)

show_total_defects_by_code_health_for(df)

# %% [markdown]
# ### [RQ2] How much longer development time is needed to resolve an issue in files with low quality source code?

# %%
healthy_mean = healthy[healthy['mean_time_for_issue_norm'].notna()]
warning_mean = warning[warning['mean_time_for_issue_norm'].notna()]
alert_mean = alert[alert['mean_time_for_issue_norm'].notna()]

fvalue, pvalue = stats.f_oneway(healthy_mean['mean_time_for_issue_norm'], warning_mean['mean_time_for_issue_norm'], alert_mean['mean_time_for_issue_norm'])
print(fvalue, pvalue)
# Out:
# 298.55451077422725 6.934042800252301e-129

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

all_groups = df[df['mean_time_for_issue_norm'].notna()]

tukey_mean = pairwise_tukeyhsd(endog=all_groups['mean_time_for_issue_norm'],
                               groups=all_groups['code_health_category'],
                               alpha=0.05)

print(tukey_mean)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
#  group1  group2 meandiff p-adj  lower   upper  reject
# -----------------------------------------------------
#   alert healthy  -0.8997 0.001  -1.026 -0.7735   True
#   alert warning  -0.5213 0.001 -0.6545  -0.388   True
# healthy warning   0.3785 0.001  0.3305  0.4265   True
# -----------------------------------------------------

# %%
def show_mean_time_in_development(df):
    ax = sns.barplot(x="code_health_category", y="mean_time_for_issue_scaled", data=df, order=['healthy', 'warning', 'alert'], palette="Blues_d")
    ax.set(xlabel='Code health category', ylabel='Mean time for Change per File', title='Mean Time per Change by Code Health category')
    plt.show(ax)
    
show_mean_time_in_development(df)

# %% [markdown]
# ### [RQ3] To what extent is the code quality of a file related to the predictability of resolving issues on time?

# %%
fvalue, pvalue = stats.f_oneway(healthy['max_time_for_issue_norm_scaled'], warning['max_time_for_issue_norm_scaled'], alert['max_time_for_issue_norm_scaled'])
print(fvalue, pvalue)
# Out:
# 742.5648781639527 1.14196813e-315

# %%
# perform Tukey's test
from statsmodels.stats.multicomp import pairwise_tukeyhsd
tukey = pairwise_tukeyhsd(endog=df['max_time_for_issue_norm_scaled'],
                          groups=df['code_health_category'],
                          alpha=0.05)

print(tukey)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
#  group1  group2 meandiff p-adj  lower   upper  reject
# -----------------------------------------------------
#   alert healthy  -0.3772 0.001 -0.4076 -0.3468   True
#   alert warning   -0.256 0.001 -0.2879 -0.2242   True
# healthy warning   0.1212 0.001  0.1104   0.132   True
# -----------------------------------------------------

# %%
def show_max_time_in_development(df):
    ax = sns.barplot(x="code_health_category", y="max_time_for_issue_scaled", data=df, order=['healthy', 'warning', 'alert'], palette="Blues_d")
    ax.set(xlabel='Code health category', ylabel='Longest time for Change per File (max)', title='Uncertainty: Maximum Time per Change by Code Health category')
    plt.show(ax)

show_max_time_in_development(df)

# %% [markdown]
# ## Other exporations

# %%
def _df_for_non_trivial_changes(df):
    """Look at modules that contain multiple issues to get a meaningful mean time in development: r increases  
       with more representative means."""
    return df[df['issues'] > 20.0]

df_corr = _df_for_non_trivial_changes(df)

corr = df_corr.corr(method ='pearson')
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_8bd42_row0_col0, #T_8bd42_row1_col1, #T_8bd42_row2_col2, #T_8bd42_row2_col12, #T_8bd42_row3_col3, #T_8bd42_row4_col4, #T_8bd42_row5_col5, #T_8bd42_row6_col6, #T_8bd42_row6_col10, #T_8bd42_row7_col7, #T_8bd42_row7_col8, #T_8bd42_row8_col7, #T_8bd42_row8_col8, #T_8bd42_row9_col9, #T_8bd42_row9_col11, #T_8bd42_row10_col6, #T_8bd42_row10_col10, #T_8bd42_row11_col9, #T_8bd42_row11_col11, #T_8bd42_row12_col2, #T_8bd42_row12_col12, #T_8bd42_row13_col13, #T_8bd42_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8bd42_row0_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_8bd42_row0_col2, #T_8bd42_row0_col5, #T_8bd42_row0_col12 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_8bd42_row0_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_8bd42_row0_col4 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_8bd42_row0_col6, #T_8bd42_row0_col10 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_8bd42_row0_col7, #T_8bd42_row0_col8 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_8bd42_row0_col9, #T_8bd42_row0_col11 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_8bd42_row0_col13, #T_8bd42_row2_col1, #T_8bd42_row12_col1, #T_8bd42_row13_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_8bd42_row0_col14 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_8bd42_row1_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_8bd42_row1_col2, #T_8bd42_row1_col12 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_8bd42_row1_col3 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_8bd42_row1_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_8bd42_row1_col5 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_8bd42_row1_col6, #T_8bd42_row1_col10 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_8bd42_row1_col7, #T_8bd42_row1_col8 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_8bd42_row1_col9, #T_8bd42_row1_col11 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_8bd42_row1_col13 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_8bd42_row1_col14 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_8bd42_row2_col0, #T_8bd42_row12_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_8bd42_row2_col3, #T_8bd42_row12_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_8bd42_row2_col4, #T_8bd42_row12_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_8bd42_row2_col5, #T_8bd42_row12_col5 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_8bd42_row2_col6, #T_8bd42_row2_col10, #T_8bd42_row6_col2, #T_8bd42_row6_col12, #T_8bd42_row10_col2, #T_8bd42_row10_col12, #T_8bd42_row12_col6, #T_8bd42_row12_col10 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_8bd42_row2_col7, #T_8bd42_row2_col8, #T_8bd42_row12_col7, #T_8bd42_row12_col8 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_8bd42_row2_col9, #T_8bd42_row2_col11, #T_8bd42_row5_col6, #T_8bd42_row5_col10, #T_8bd42_row6_col5, #T_8bd42_row6_col13, #T_8bd42_row9_col2, #T_8bd42_row9_col12, #T_8bd42_row10_col5, #T_8bd42_row10_col13, #T_8bd42_row11_col2, #T_8bd42_row11_col12, #T_8bd42_row12_col9, #T_8bd42_row12_col11, #T_8bd42_row14_col6, #T_8bd42_row14_col10 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_8bd42_row2_col13, #T_8bd42_row2_col14, #T_8bd42_row12_col13, #T_8bd42_row12_col14, #T_8bd42_row13_col2, #T_8bd42_row13_col12, #T_8bd42_row14_col2, #T_8bd42_row14_col12 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_8bd42_row3_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_8bd42_row3_col1 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_8bd42_row3_col2, #T_8bd42_row3_col12 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_8bd42_row3_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_8bd42_row3_col5 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_8bd42_row3_col6, #T_8bd42_row3_col9, #T_8bd42_row3_col10, #T_8bd42_row3_col11 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_8bd42_row3_col7, #T_8bd42_row3_col8 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_8bd42_row3_col13 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_8bd42_row3_col14 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_8bd42_row4_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_8bd42_row4_col1, #T_8bd42_row4_col2, #T_8bd42_row4_col3, #T_8bd42_row4_col5, #T_8bd42_row4_col6, #T_8bd42_row4_col7, #T_8bd42_row4_col8, #T_8bd42_row4_col9, #T_8bd42_row4_col10, #T_8bd42_row4_col11, #T_8bd42_row4_col12, #T_8bd42_row4_col13, #T_8bd42_row4_col14, #T_8bd42_row7_col0, #T_8bd42_row8_col0, #T_8bd42_row14_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8bd42_row5_col0, #T_8bd42_row14_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_8bd42_row5_col1 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_8bd42_row5_col2, #T_8bd42_row5_col12 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_8bd42_row5_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_8bd42_row5_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_8bd42_row5_col7, #T_8bd42_row5_col8 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_8bd42_row5_col9, #T_8bd42_row5_col11 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_8bd42_row5_col13, #T_8bd42_row14_col5 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_8bd42_row5_col14, #T_8bd42_row9_col5, #T_8bd42_row11_col5 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_8bd42_row6_col0, #T_8bd42_row10_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_8bd42_row6_col1, #T_8bd42_row7_col14, #T_8bd42_row8_col14, #T_8bd42_row10_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_8bd42_row6_col3, #T_8bd42_row9_col3, #T_8bd42_row10_col3, #T_8bd42_row11_col3 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_8bd42_row6_col4, #T_8bd42_row9_col4, #T_8bd42_row10_col4, #T_8bd42_row11_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_8bd42_row6_col7, #T_8bd42_row6_col8, #T_8bd42_row9_col7, #T_8bd42_row9_col8, #T_8bd42_row10_col7, #T_8bd42_row10_col8, #T_8bd42_row11_col7, #T_8bd42_row11_col8 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_8bd42_row6_col9, #T_8bd42_row6_col11, #T_8bd42_row9_col6, #T_8bd42_row9_col10, #T_8bd42_row10_col9, #T_8bd42_row10_col11, #T_8bd42_row11_col6, #T_8bd42_row11_col10 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_8bd42_row6_col14, #T_8bd42_row10_col14 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_8bd42_row7_col1, #T_8bd42_row8_col1 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_8bd42_row7_col2, #T_8bd42_row7_col12, #T_8bd42_row8_col2, #T_8bd42_row8_col12 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_8bd42_row7_col3, #T_8bd42_row8_col3 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_8bd42_row7_col4, #T_8bd42_row8_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_8bd42_row7_col5, #T_8bd42_row8_col5 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_8bd42_row7_col6, #T_8bd42_row7_col10, #T_8bd42_row8_col6, #T_8bd42_row8_col10, #T_8bd42_row9_col1, #T_8bd42_row11_col1 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_8bd42_row7_col9, #T_8bd42_row7_col11, #T_8bd42_row7_col13, #T_8bd42_row8_col9, #T_8bd42_row8_col11, #T_8bd42_row8_col13 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_8bd42_row9_col0, #T_8bd42_row11_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_8bd42_row9_col13, #T_8bd42_row9_col14, #T_8bd42_row11_col13, #T_8bd42_row11_col14, #T_8bd42_row13_col9, #T_8bd42_row13_col11 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_8bd42_row13_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_8bd42_row13_col1 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_8bd42_row13_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_8bd42_row13_col5 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_8bd42_row13_col6, #T_8bd42_row13_col10 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_8bd42_row13_col7, #T_8bd42_row13_col8 {
#   background-color: #d1dae9;
#   color: #000000;
